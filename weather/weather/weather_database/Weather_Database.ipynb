# %%
# Import the dependencies.
import pandas as pd
import numpy as np
from citipy import citipy

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Create a set of 2000 random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
##Get the nearest city using the citipy module.
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 734

# %%
##Get the nearest city using the citipy module.

print (city)
# Out:
# khatanga

# %%
#Create Empty City Data list
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

#Create Counters
record_count = 1
set_count = 1

# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

#Loop through all the cities in our list
##first try: for i in range(len(cities)):  only gets index, not city name

for i, city in enumerate(cities):
    
    #Group cities in sets of 50 for logging (if multiple of 50 and greater/equal to 50)
    if (i % 50==0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # create endpoint URL - remove spaces from city name to ensure full name is searched
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    #Run API request
    try:
        #parse the json and retrieve
        city_weather = requests.get(city_url).json()
        #parse data
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_desc = city_weather["weather"][0]["description"]
        

        #append data
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_desc})
        
        #if error skip
        
    except:
        print("City not found. Skipping...")
        pass
    
#indicate data is complete
print("----------------------------")
print("Data Retriecal Complete     ")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | rikitea
# Processing Record 2 of Set 1 | juba
# Processing Record 3 of Set 1 | progreso
# Processing Record 4 of Set 1 | sitka
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | kuusamo
# Processing Record 7 of Set 1 | iberia
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | lata
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | hopewell
# Processing Record 12 of Set 1 | kodiak
# Processing Record 13 of Set 1 | mahebourg
# Processing Record 14 of Set 1 | chokurdakh
# Processing Record 15 of Set 1 | mapimi
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | hasaki
# Processing Record 18 of Set 1 | avarua
# Processing Record 19 of Set 1 | cape town
# Processing Record 20 of Set 1 | barrow
# Processing Record 21 of Set 1 | banmo
# City not found. Skipping...
# Processing Record 22 of Set 1 | severnyy
# Processing Record 23 of Set 1 | albany
# Processing Record 24 of Set 1 | port elizabeth
# Processing Record 25 of Set 1 | uarini
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | bambous virieux
# Processing Record 28 of Set 1 | molepolole
# Processing Record 29 of Set 1 | mastic beach
# Processing Record 30 of Set 1 | tura
# Processing Record 31 of Set 1 | labuhan
# Processing Record 32 of Set 1 | new norfolk
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | georgetown
# Processing Record 35 of Set 1 | martapura
# Processing Record 36 of Set 1 | camacha
# Processing Record 37 of Set 1 | kaitangata
# Processing Record 38 of Set 1 | temiscaming
# Processing Record 39 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 40 of Set 1 | yellowknife
# Processing Record 41 of Set 1 | agua blanca
# Processing Record 42 of Set 1 | la ronge
# Processing Record 43 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | kapaa
# Processing Record 47 of Set 1 | isangel
# Processing Record 48 of Set 1 | kamaishi
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | punta arenas
# Processing Record 1 of Set 2 | laguna
# Processing Record 2 of Set 2 | makakilo city
# Processing Record 3 of Set 2 | eluru
# Processing Record 4 of Set 2 | carnarvon
# Processing Record 5 of Set 2 | anahuac
# Processing Record 6 of Set 2 | ilulissat
# Processing Record 7 of Set 2 | baykit
# Processing Record 8 of Set 2 | penon blanco
# Processing Record 9 of Set 2 | namibe
# Processing Record 10 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 11 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 2 | bell ville
# Processing Record 13 of Set 2 | leningradskiy
# Processing Record 14 of Set 2 | ribeira grande
# Processing Record 15 of Set 2 | paamiut
# Processing Record 16 of Set 2 | ahuimanu
# Processing Record 17 of Set 2 | flinders
# Processing Record 18 of Set 2 | sorland
# Processing Record 19 of Set 2 | faya
# Processing Record 20 of Set 2 | bluff
# Processing Record 21 of Set 2 | fort nelson
# Processing Record 22 of Set 2 | hovd
# Processing Record 23 of Set 2 | chiautla
# Processing Record 24 of Set 2 | longyearbyen
# Processing Record 25 of Set 2 | walvis bay
# Processing Record 26 of Set 2 | baghdad
# Processing Record 27 of Set 2 | yulara
# Processing Record 28 of Set 2 | mataura
# Processing Record 29 of Set 2 | victoria
# Processing Record 30 of Set 2 | mayo
# Processing Record 31 of Set 2 | hobart
# Processing Record 32 of Set 2 | kieta
# Processing Record 33 of Set 2 | lompoc
# Processing Record 34 of Set 2 | tevaitoa
# Processing Record 35 of Set 2 | grand gaube
# Processing Record 36 of Set 2 | hithadhoo
# Processing Record 37 of Set 2 | saskylakh
# Processing Record 38 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 2 | butaritari
# Processing Record 40 of Set 2 | gustrow
# Processing Record 41 of Set 2 | togur
# Processing Record 42 of Set 2 | margate
# Processing Record 43 of Set 2 | bara
# Processing Record 44 of Set 2 | iqaluit
# Processing Record 45 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 46 of Set 2 | boguchany
# Processing Record 47 of Set 2 | tibati
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | cradock
# Processing Record 50 of Set 2 | provideniya
# Processing Record 1 of Set 3 | olafsvik
# Processing Record 2 of Set 3 | caconda
# Processing Record 3 of Set 3 | point pedro
# Processing Record 4 of Set 3 | santa maria
# Processing Record 5 of Set 3 | karatau
# Processing Record 6 of Set 3 | cidreira
# Processing Record 7 of Set 3 | tuatapere
# Processing Record 8 of Set 3 | saldanha
# Processing Record 9 of Set 3 | waitati
# Processing Record 10 of Set 3 | nikolskoye
# Processing Record 11 of Set 3 | ijaki
# City not found. Skipping...
# Processing Record 12 of Set 3 | upernavik
# Processing Record 13 of Set 3 | rocha
# Processing Record 14 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 15 of Set 3 | atuona
# Processing Record 16 of Set 3 | swan hill
# Processing Record 17 of Set 3 | krasnoselkup
# Processing Record 18 of Set 3 | mar del plata
# Processing Record 19 of Set 3 | mana
# Processing Record 20 of Set 3 | puerto ayora
# Processing Record 21 of Set 3 | port alfred
# Processing Record 22 of Set 3 | yelan-koleno
# Processing Record 23 of Set 3 | khovu-aksy
# Processing Record 24 of Set 3 | zhuhai
# Processing Record 25 of Set 3 | luderitz
# Processing Record 26 of Set 3 | amuntai
# Processing Record 27 of Set 3 | seguela
# Processing Record 28 of Set 3 | ligayan
# Processing Record 29 of Set 3 | poum
# Processing Record 30 of Set 3 | pevek
# Processing Record 31 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 3 | rosarito
# Processing Record 33 of Set 3 | thouars
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | tuktoyaktuk
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | hermanus
# Processing Record 40 of Set 3 | kallaste
# Processing Record 41 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 3 | constitucion
# Processing Record 43 of Set 3 | aykhal
# Processing Record 44 of Set 3 | hulan
# Processing Record 45 of Set 3 | palmer
# Processing Record 46 of Set 3 | kyaikkami
# Processing Record 47 of Set 3 | sola
# Processing Record 48 of Set 3 | calvinia
# Processing Record 49 of Set 3 | cherskiy
# Processing Record 50 of Set 3 | katsuura
# Processing Record 1 of Set 4 | vestmanna
# Processing Record 2 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 4 | portales
# Processing Record 4 of Set 4 | banfora
# Processing Record 5 of Set 4 | lagoa
# Processing Record 6 of Set 4 | gornopravdinsk
# Processing Record 7 of Set 4 | caucasia
# Processing Record 8 of Set 4 | saint george
# Processing Record 9 of Set 4 | todos santos
# Processing Record 10 of Set 4 | faanui
# Processing Record 11 of Set 4 | pangnirtung
# Processing Record 12 of Set 4 | castanos
# Processing Record 13 of Set 4 | longjiang
# Processing Record 14 of Set 4 | yumen
# Processing Record 15 of Set 4 | kavieng
# Processing Record 16 of Set 4 | prince george
# Processing Record 17 of Set 4 | celestun
# Processing Record 18 of Set 4 | dera din panah
# City not found. Skipping...
# Processing Record 19 of Set 4 | arraial do cabo
# Processing Record 20 of Set 4 | eslamshahr
# Processing Record 21 of Set 4 | macieira de cambra
# Processing Record 22 of Set 4 | saint-philippe
# Processing Record 23 of Set 4 | santiago
# Processing Record 24 of Set 4 | santiago de cao
# Processing Record 25 of Set 4 | qaanaaq
# Processing Record 26 of Set 4 | karasjok
# Processing Record 27 of Set 4 | khash
# Processing Record 28 of Set 4 | primorsk
# Processing Record 29 of Set 4 | srednekolymsk
# Processing Record 30 of Set 4 | narasannapeta
# Processing Record 31 of Set 4 | kayes
# Processing Record 32 of Set 4 | turayf
# Processing Record 33 of Set 4 | oksfjord
# Processing Record 34 of Set 4 | colac
# Processing Record 35 of Set 4 | tilichiki
# Processing Record 36 of Set 4 | hemnesberget
# Processing Record 37 of Set 4 | cacoal
# Processing Record 38 of Set 4 | meulaboh
# Processing Record 39 of Set 4 | hambantota
# Processing Record 40 of Set 4 | hirado
# Processing Record 41 of Set 4 | durango
# Processing Record 42 of Set 4 | rawson
# Processing Record 43 of Set 4 | abay
# Processing Record 44 of Set 4 | la tuque
# Processing Record 45 of Set 4 | luanda
# Processing Record 46 of Set 4 | zyryanskoye
# Processing Record 47 of Set 4 | chapais
# Processing Record 48 of Set 4 | vicksburg
# Processing Record 49 of Set 4 | souillac
# Processing Record 50 of Set 4 | edendale
# Processing Record 1 of Set 5 | lasa
# Processing Record 2 of Set 5 | kahului
# Processing Record 3 of Set 5 | esperance
# Processing Record 4 of Set 5 | nanortalik
# Processing Record 5 of Set 5 | igarka
# Processing Record 6 of Set 5 | norman wells
# Processing Record 7 of Set 5 | sao joao da barra
# Processing Record 8 of Set 5 | nioro
# Processing Record 9 of Set 5 | marau
# Processing Record 10 of Set 5 | rundu
# Processing Record 11 of Set 5 | agadir
# Processing Record 12 of Set 5 | cukai
# Processing Record 13 of Set 5 | berlevag
# Processing Record 14 of Set 5 | vardo
# Processing Record 15 of Set 5 | bereslavka
# Processing Record 16 of Set 5 | las margaritas
# Processing Record 17 of Set 5 | carman
# Processing Record 18 of Set 5 | airai
# Processing Record 19 of Set 5 | gebre guracha
# Processing Record 20 of Set 5 | cockburn town
# Processing Record 21 of Set 5 | jamestown
# Processing Record 22 of Set 5 | camopi
# Processing Record 23 of Set 5 | sawtell
# Processing Record 24 of Set 5 | torbay
# Processing Record 25 of Set 5 | sananduva
# Processing Record 26 of Set 5 | meridian
# Processing Record 27 of Set 5 | butte
# Processing Record 28 of Set 5 | aldan
# Processing Record 29 of Set 5 | tasiilaq
# Processing Record 30 of Set 5 | padang
# Processing Record 31 of Set 5 | pinawa
# Processing Record 32 of Set 5 | shenkursk
# Processing Record 33 of Set 5 | tabriz
# Processing Record 34 of Set 5 | doha
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | ambon
# Processing Record 37 of Set 5 | fortuna
# Processing Record 38 of Set 5 | kashi
# Processing Record 39 of Set 5 | gazanjyk
# Processing Record 40 of Set 5 | ugoofaaru
# Processing Record 41 of Set 5 | ulladulla
# Processing Record 42 of Set 5 | mount isa
# Processing Record 43 of Set 5 | ponta do sol
# Processing Record 44 of Set 5 | pitimbu
# Processing Record 45 of Set 5 | abha
# Processing Record 46 of Set 5 | igboho
# Processing Record 47 of Set 5 | najran
# Processing Record 48 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 5 | baiyin
# Processing Record 50 of Set 5 | ketchikan
# Processing Record 1 of Set 6 | huarmey
# Processing Record 2 of Set 6 | charters towers
# Processing Record 3 of Set 6 | pinotepa nacional
# Processing Record 4 of Set 6 | naco
# Processing Record 5 of Set 6 | forbes
# Processing Record 6 of Set 6 | ixtapa
# Processing Record 7 of Set 6 | cabo san lucas
# Processing Record 8 of Set 6 | deputatskiy
# Processing Record 9 of Set 6 | khor
# Processing Record 10 of Set 6 | sibolga
# Processing Record 11 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 12 of Set 6 | gat
# Processing Record 13 of Set 6 | bukachacha
# Processing Record 14 of Set 6 | lebu
# Processing Record 15 of Set 6 | freeport
# Processing Record 16 of Set 6 | portland
# Processing Record 17 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 18 of Set 6 | nishihara
# Processing Record 19 of Set 6 | ivankiv
# Processing Record 20 of Set 6 | harnosand
# Processing Record 21 of Set 6 | guerrero negro
# Processing Record 22 of Set 6 | haines junction
# Processing Record 23 of Set 6 | nouadhibou
# Processing Record 24 of Set 6 | coquimbo
# Processing Record 25 of Set 6 | qaqortoq
# Processing Record 26 of Set 6 | tyret pervaya
# Processing Record 27 of Set 6 | wanning
# Processing Record 28 of Set 6 | kidal
# Processing Record 29 of Set 6 | kaeo
# Processing Record 30 of Set 6 | sungaipenuh
# Processing Record 31 of Set 6 | estelle
# Processing Record 32 of Set 6 | garhi khairo
# Processing Record 33 of Set 6 | ballina
# Processing Record 34 of Set 6 | kaduqli
# Processing Record 35 of Set 6 | riohacha
# Processing Record 36 of Set 6 | champerico
# Processing Record 37 of Set 6 | datong
# Processing Record 38 of Set 6 | macusani
# Processing Record 39 of Set 6 | axim
# Processing Record 40 of Set 6 | zhigansk
# Processing Record 41 of Set 6 | portsmouth
# Processing Record 42 of Set 6 | motygino
# Processing Record 43 of Set 6 | mangrol
# Processing Record 44 of Set 6 | monastyrshchina
# Processing Record 45 of Set 6 | maldonado
# Processing Record 46 of Set 6 | lazaro cardenas
# Processing Record 47 of Set 6 | skjervoy
# Processing Record 48 of Set 6 | port macquarie
# Processing Record 49 of Set 6 | along
# Processing Record 50 of Set 6 | maragogi
# Processing Record 1 of Set 7 | vila velha
# Processing Record 2 of Set 7 | alice springs
# Processing Record 3 of Set 7 | kuryk
# Processing Record 4 of Set 7 | wyszkow
# Processing Record 5 of Set 7 | ermelo
# Processing Record 6 of Set 7 | dikson
# Processing Record 7 of Set 7 | okhotsk
# Processing Record 8 of Set 7 | pangoa
# Processing Record 9 of Set 7 | gondanglegi
# Processing Record 10 of Set 7 | bandarbeyla
# Processing Record 11 of Set 7 | ostrovnoy
# Processing Record 12 of Set 7 | tiksi
# Processing Record 13 of Set 7 | tukrah
# Processing Record 14 of Set 7 | talnakh
# Processing Record 15 of Set 7 | port lincoln
# Processing Record 16 of Set 7 | ancud
# Processing Record 17 of Set 7 | saint-augustin
# Processing Record 18 of Set 7 | buala
# Processing Record 19 of Set 7 | port-cartier
# Processing Record 20 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 21 of Set 7 | husavik
# Processing Record 22 of Set 7 | kununurra
# Processing Record 23 of Set 7 | coswig
# Processing Record 24 of Set 7 | sangar
# Processing Record 25 of Set 7 | linfen
# Processing Record 26 of Set 7 | college
# Processing Record 27 of Set 7 | noumea
# Processing Record 28 of Set 7 | klaksvik
# Processing Record 29 of Set 7 | vostok
# Processing Record 30 of Set 7 | arandis
# Processing Record 31 of Set 7 | bengkulu
# Processing Record 32 of Set 7 | merauke
# Processing Record 33 of Set 7 | roebourne
# Processing Record 34 of Set 7 | samarai
# Processing Record 35 of Set 7 | henties bay
# Processing Record 36 of Set 7 | sovetskiy
# Processing Record 37 of Set 7 | bagdarin
# Processing Record 38 of Set 7 | tessalit
# Processing Record 39 of Set 7 | tuensang
# Processing Record 40 of Set 7 | acapulco
# Processing Record 41 of Set 7 | kollo
# Processing Record 42 of Set 7 | edd
# Processing Record 43 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 44 of Set 7 | port hawkesbury
# Processing Record 45 of Set 7 | kupang
# Processing Record 46 of Set 7 | santa cruz de la palma
# Processing Record 47 of Set 7 | totma
# Processing Record 48 of Set 7 | oriximina
# Processing Record 49 of Set 7 | eldikan
# City not found. Skipping...
# Processing Record 50 of Set 7 | placido de castro
# Processing Record 1 of Set 8 | touros
# Processing Record 2 of Set 8 | amapa
# Processing Record 3 of Set 8 | darnah
# Processing Record 4 of Set 8 | mount gambier
# Processing Record 5 of Set 8 | san rafael
# Processing Record 6 of Set 8 | thomasville
# Processing Record 7 of Set 8 | west lafayette
# Processing Record 8 of Set 8 | beira
# Processing Record 9 of Set 8 | gemena
# Processing Record 10 of Set 8 | arlit
# Processing Record 11 of Set 8 | sarangani
# Processing Record 12 of Set 8 | sandovo
# Processing Record 13 of Set 8 | pisco
# Processing Record 14 of Set 8 | vengerovo
# Processing Record 15 of Set 8 | tigil
# Processing Record 16 of Set 8 | iquitos
# Processing Record 17 of Set 8 | lorengau
# Processing Record 18 of Set 8 | san vicente
# Processing Record 19 of Set 8 | trogir
# Processing Record 20 of Set 8 | fairbanks
# Processing Record 21 of Set 8 | phan rang
# City not found. Skipping...
# Processing Record 22 of Set 8 | hofn
# Processing Record 23 of Set 8 | saginaw
# Processing Record 24 of Set 8 | iztapa
# Processing Record 25 of Set 8 | nelson bay
# Processing Record 26 of Set 8 | adrar
# Processing Record 27 of Set 8 | luganville
# Processing Record 28 of Set 8 | grong
# Processing Record 29 of Set 8 | marawi
# Processing Record 30 of Set 8 | aksarka
# Processing Record 31 of Set 8 | vao
# Processing Record 32 of Set 8 | xining
# Processing Record 33 of Set 8 | kasongo
# Processing Record 34 of Set 8 | san andres
# Processing Record 35 of Set 8 | alindao
# Processing Record 36 of Set 8 | changji
# Processing Record 37 of Set 8 | frydlant nad ostravici
# Processing Record 38 of Set 8 | talgar
# Processing Record 39 of Set 8 | luwuk
# Processing Record 40 of Set 8 | puerto cortes
# City not found. Skipping...
# Processing Record 41 of Set 8 | clyde river
# Processing Record 42 of Set 8 | rio de janeiro
# Processing Record 43 of Set 8 | jarjis
# City not found. Skipping...
# Processing Record 44 of Set 8 | vila franca do campo
# Processing Record 45 of Set 8 | bolshiye kaybitsy
# City not found. Skipping...
# Processing Record 46 of Set 8 | seoul
# Processing Record 47 of Set 8 | kayerkan
# Processing Record 48 of Set 8 | plettenberg bay
# Processing Record 49 of Set 8 | sultepec
# Processing Record 50 of Set 8 | bilibino
# Processing Record 1 of Set 9 | at-bashi
# Processing Record 2 of Set 9 | huayang
# Processing Record 3 of Set 9 | thyolo
# Processing Record 4 of Set 9 | jiroft
# City not found. Skipping...
# Processing Record 5 of Set 9 | tabat
# Processing Record 6 of Set 9 | cruzeiro do sul
# Processing Record 7 of Set 9 | rincon
# Processing Record 8 of Set 9 | tidore
# City not found. Skipping...
# Processing Record 9 of Set 9 | poya
# Processing Record 10 of Set 9 | kaka
# Processing Record 11 of Set 9 | qasigiannguit
# Processing Record 12 of Set 9 | wulanhaote
# City not found. Skipping...
# Processing Record 13 of Set 9 | dubrovnik
# Processing Record 14 of Set 9 | sabha
# Processing Record 15 of Set 9 | torit
# Processing Record 16 of Set 9 | leshukonskoye
# Processing Record 17 of Set 9 | port hardy
# Processing Record 18 of Set 9 | hof
# Processing Record 19 of Set 9 | anloga
# Processing Record 20 of Set 9 | tirano
# Processing Record 21 of Set 9 | havre-saint-pierre
# Processing Record 22 of Set 9 | lugovoy
# Processing Record 23 of Set 9 | grindavik
# Processing Record 24 of Set 9 | itaituba
# Processing Record 25 of Set 9 | loveland
# Processing Record 26 of Set 9 | san quintin
# Processing Record 27 of Set 9 | uyuni
# Processing Record 28 of Set 9 | pamanukan
# Processing Record 29 of Set 9 | talakan
# Processing Record 30 of Set 9 | desur
# Processing Record 31 of Set 9 | goderich
# Processing Record 32 of Set 9 | sampit
# Processing Record 33 of Set 9 | altamira
# Processing Record 34 of Set 9 | tutoia
# Processing Record 35 of Set 9 | sao filipe
# Processing Record 36 of Set 9 | balimo
# City not found. Skipping...
# Processing Record 37 of Set 9 | tazovskiy
# Processing Record 38 of Set 9 | locri
# Processing Record 39 of Set 9 | anar darreh
# City not found. Skipping...
# Processing Record 40 of Set 9 | alanya
# Processing Record 41 of Set 9 | taoudenni
# Processing Record 42 of Set 9 | santa isabel do rio negro
# Processing Record 43 of Set 9 | kyra
# Processing Record 44 of Set 9 | pathein
# Processing Record 45 of Set 9 | turukhansk
# Processing Record 46 of Set 9 | codrington
# Processing Record 47 of Set 9 | ukiah
# Processing Record 48 of Set 9 | roma
# Processing Record 49 of Set 9 | kolding
# Processing Record 50 of Set 9 | paradwip
# City not found. Skipping...
# Processing Record 1 of Set 10 | bardiyah
# Processing Record 2 of Set 10 | hobyo
# Processing Record 3 of Set 10 | buraydah
# Processing Record 4 of Set 10 | jales
# Processing Record 5 of Set 10 | borogontsy
# Processing Record 6 of Set 10 | veraval
# Processing Record 7 of Set 10 | bairiki
# Processing Record 8 of Set 10 | coihaique
# Processing Record 9 of Set 10 | lulea
# Processing Record 10 of Set 10 | shar
# Processing Record 11 of Set 10 | dauphin
# Processing Record 12 of Set 10 | campbell river
# Processing Record 13 of Set 10 | dryden
# Processing Record 14 of Set 10 | soe
# Processing Record 15 of Set 10 | kasiri
# Processing Record 16 of Set 10 | saint marys
# Processing Record 17 of Set 10 | skuodas
# Processing Record 18 of Set 10 | prince rupert
# Processing Record 19 of Set 10 | chuy
# Processing Record 20 of Set 10 | rio gallegos
# Processing Record 21 of Set 10 | khonuu
# City not found. Skipping...
# Processing Record 22 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 23 of Set 10 | kargasok
# Processing Record 24 of Set 10 | praya
# Processing Record 25 of Set 10 | jumla
# Processing Record 26 of Set 10 | winnemucca
# Processing Record 27 of Set 10 | urumqi
# Processing Record 28 of Set 10 | kartaly
# Processing Record 29 of Set 10 | joshimath
# Processing Record 30 of Set 10 | paraiso
# Processing Record 31 of Set 10 | chemax
# Processing Record 32 of Set 10 | inta
# Processing Record 33 of Set 10 | kruisfontein
# Processing Record 34 of Set 10 | felipe carrillo puerto
# Processing Record 35 of Set 10 | masumbwe
# Processing Record 36 of Set 10 | nha trang
# Processing Record 37 of Set 10 | nurota
# Processing Record 38 of Set 10 | moorhead
# Processing Record 39 of Set 10 | gezing
# Processing Record 40 of Set 10 | kultuk
# Processing Record 41 of Set 10 | shimoda
# Processing Record 42 of Set 10 | thinadhoo
# Processing Record 43 of Set 10 | pauini
# Processing Record 44 of Set 10 | takapau
# Processing Record 45 of Set 10 | batemans bay
# Processing Record 46 of Set 10 | luz
# Processing Record 47 of Set 10 | puerto escondido
# Processing Record 48 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 49 of Set 10 | beringovskiy
# Processing Record 50 of Set 10 | aksay
# Processing Record 1 of Set 11 | sorong
# Processing Record 2 of Set 11 | pando
# Processing Record 3 of Set 11 | brae
# Processing Record 4 of Set 11 | nurlat
# Processing Record 5 of Set 11 | darhan
# Processing Record 6 of Set 11 | san patricio
# Processing Record 7 of Set 11 | wajima
# Processing Record 8 of Set 11 | hamilton
# Processing Record 9 of Set 11 | alofi
# Processing Record 10 of Set 11 | pangkalanbuun
# Processing Record 11 of Set 11 | san vicente de canete
# Processing Record 12 of Set 11 | calama
# Processing Record 13 of Set 11 | marystown
# Processing Record 14 of Set 11 | saint-joseph
# Processing Record 15 of Set 11 | bayir
# Processing Record 16 of Set 11 | bathsheba
# Processing Record 17 of Set 11 | moura
# Processing Record 18 of Set 11 | viksoyri
# City not found. Skipping...
# Processing Record 19 of Set 11 | nhulunbuy
# Processing Record 20 of Set 11 | san roque
# Processing Record 21 of Set 11 | sarankhola
# Processing Record 22 of Set 11 | marzuq
# Processing Record 23 of Set 11 | bambanglipuro
# Processing Record 24 of Set 11 | aripuana
# Processing Record 25 of Set 11 | njombe
# Processing Record 26 of Set 11 | moree
# Processing Record 27 of Set 11 | artigas
# Processing Record 28 of Set 11 | ericeira
# Processing Record 29 of Set 11 | kisangani
# Processing Record 30 of Set 11 | sinnamary
# Processing Record 31 of Set 11 | tromso
# Processing Record 32 of Set 11 | san policarpo
# Processing Record 33 of Set 11 | zonnebeke
# Processing Record 34 of Set 11 | khorramshahr
# Processing Record 35 of Set 11 | vsevolozhsk
# Processing Record 36 of Set 11 | lavrentiya
# Processing Record 37 of Set 11 | broome
# Processing Record 38 of Set 11 | makung
# City not found. Skipping...
# Processing Record 39 of Set 11 | horsham
# Processing Record 40 of Set 11 | kampene
# Processing Record 41 of Set 11 | fort-shevchenko
# Processing Record 42 of Set 11 | jardim
# Processing Record 43 of Set 11 | ban nahin
# Processing Record 44 of Set 11 | bom jesus do galho
# Processing Record 45 of Set 11 | aplahoue
# Processing Record 46 of Set 11 | garelochhead
# Processing Record 47 of Set 11 | nemuro
# Processing Record 48 of Set 11 | yichun
# Processing Record 49 of Set 11 | black forest
# Processing Record 50 of Set 11 | kirakira
# Processing Record 1 of Set 12 | mozarlandia
# Processing Record 2 of Set 12 | ribeira do pombal
# Processing Record 3 of Set 12 | yar-sale
# Processing Record 4 of Set 12 | nyurba
# Processing Record 5 of Set 12 | weymouth
# Processing Record 6 of Set 12 | nanakuli
# Processing Record 7 of Set 12 | sur
# Processing Record 8 of Set 12 | fort saint john
# City not found. Skipping...
# Processing Record 9 of Set 12 | corowa
# Processing Record 10 of Set 12 | nicoya
# Processing Record 11 of Set 12 | fare
# Processing Record 12 of Set 12 | jaysingpur
# Processing Record 13 of Set 12 | izhma
# Processing Record 14 of Set 12 | mattru
# Processing Record 15 of Set 12 | saint-louis
# Processing Record 16 of Set 12 | bosaso
# Processing Record 17 of Set 12 | poopo
# Processing Record 18 of Set 12 | vestmannaeyjar
# Processing Record 19 of Set 12 | huaraz
# Processing Record 20 of Set 12 | tagusao
# Processing Record 21 of Set 12 | novobelokatay
# Processing Record 22 of Set 12 | maralal
# Processing Record 23 of Set 12 | iwanai
# Processing Record 24 of Set 12 | saint anthony
# Processing Record 25 of Set 12 | bayan
# Processing Record 26 of Set 12 | asau
# Processing Record 27 of Set 12 | charagua
# Processing Record 28 of Set 12 | bam
# Processing Record 29 of Set 12 | kharp
# Processing Record 30 of Set 12 | malakal
# Processing Record 31 of Set 12 | machiques
# Processing Record 32 of Set 12 | berezovyy
# Processing Record 33 of Set 12 | kloulklubed
# Processing Record 34 of Set 12 | cotonou
# Processing Record 35 of Set 12 | ahipara
# Processing Record 36 of Set 12 | boromo
# Processing Record 37 of Set 12 | irondequoit
# Processing Record 38 of Set 12 | parabel
# Processing Record 39 of Set 12 | hellvik
# Processing Record 40 of Set 12 | bowen
# Processing Record 41 of Set 12 | koungou
# Processing Record 42 of Set 12 | bac lieu
# Processing Record 43 of Set 12 | orange cove
# Processing Record 44 of Set 12 | dunbar
# Processing Record 45 of Set 12 | marsh harbour
# Processing Record 46 of Set 12 | diffa
# Processing Record 47 of Set 12 | kadaya
# Processing Record 48 of Set 12 | praia
# Processing Record 49 of Set 12 | severo-kurilsk
# Processing Record 50 of Set 12 | antofagasta
# Processing Record 1 of Set 13 | iquique
# Processing Record 2 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 3 of Set 13 | nago
# Processing Record 4 of Set 13 | afzalpur
# Processing Record 5 of Set 13 | kristiansund
# Processing Record 6 of Set 13 | nantucket
# Processing Record 7 of Set 13 | vanino
# Processing Record 8 of Set 13 | beloha
# Processing Record 9 of Set 13 | kingsville
# Processing Record 10 of Set 13 | canita
# Processing Record 11 of Set 13 | chernivtsi
# Processing Record 12 of Set 13 | kaliua
# Processing Record 13 of Set 13 | asfi
# Processing Record 14 of Set 13 | baruun-urt
# Processing Record 15 of Set 13 | masunga
# Processing Record 16 of Set 13 | arman
# Processing Record 17 of Set 13 | ulaangom
# Processing Record 18 of Set 13 | pervomayskoye
# Processing Record 19 of Set 13 | maniitsoq
# Processing Record 20 of Set 13 | manjacaze
# Processing Record 21 of Set 13 | beberibe
# Processing Record 22 of Set 13 | seydi
# Processing Record 23 of Set 13 | arawa
# Processing Record 24 of Set 13 | manta
# Processing Record 25 of Set 13 | manaus
# Processing Record 26 of Set 13 | kalmunai
# Processing Record 27 of Set 13 | korla
# Processing Record 28 of Set 13 | salalah
# Processing Record 29 of Set 13 | chicama
# Processing Record 30 of Set 13 | verkhoyansk
# Processing Record 31 of Set 13 | napoleon
# Processing Record 32 of Set 13 | novyy urengoy
# Processing Record 33 of Set 13 | yeletskiy
# City not found. Skipping...
# Processing Record 34 of Set 13 | quatre cocos
# Processing Record 35 of Set 13 | kolyshley
# Processing Record 36 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 37 of Set 13 | lafia
# Processing Record 38 of Set 13 | puerto colombia
# Processing Record 39 of Set 13 | lillooet
# Processing Record 40 of Set 13 | araguari
# Processing Record 41 of Set 13 | ajdabiya
# Processing Record 42 of Set 13 | saryozek
# Processing Record 43 of Set 13 | sambava
# Processing Record 44 of Set 13 | auki
# Processing Record 45 of Set 13 | taltal
# Processing Record 46 of Set 13 | kimbe
# Processing Record 47 of Set 13 | kavaratti
# Processing Record 48 of Set 13 | manokwari
# Processing Record 49 of Set 13 | kandrian
# Processing Record 50 of Set 13 | severobaykalsk
# Processing Record 1 of Set 14 | rognan
# Processing Record 2 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 3 of Set 14 | dulce nombre de culmi
# Processing Record 4 of Set 14 | belyy yar
# Processing Record 5 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 14 | thabazimbi
# Processing Record 7 of Set 14 | chengde
# Processing Record 8 of Set 14 | cambrils
# Processing Record 9 of Set 14 | sisimiut
# Processing Record 10 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 11 of Set 14 | amahai
# Processing Record 12 of Set 14 | lermontovka
# Processing Record 13 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 14 of Set 14 | abu samrah
# Processing Record 15 of Set 14 | normandin
# Processing Record 16 of Set 14 | bubaque
# Processing Record 17 of Set 14 | peterhead
# Processing Record 18 of Set 14 | sale
# Processing Record 19 of Set 14 | teluknaga
# Processing Record 20 of Set 14 | monopoli
# Processing Record 21 of Set 14 | khani
# Processing Record 22 of Set 14 | suntar
# Processing Record 23 of Set 14 | turcianske teplice
# Processing Record 24 of Set 14 | lashio
# Processing Record 25 of Set 14 | stromness
# Processing Record 26 of Set 14 | ankara
# Processing Record 27 of Set 14 | gaozhou
# Processing Record 28 of Set 14 | tiarei
# Processing Record 29 of Set 14 | lahad datu
# Processing Record 30 of Set 14 | abonnema
# Processing Record 31 of Set 14 | kampong thum
# Processing Record 32 of Set 14 | narrabri
# Processing Record 33 of Set 14 | rameshki
# Processing Record 34 of Set 14 | zhuanghe
# Processing Record 35 of Set 14 | serenje
# Processing Record 36 of Set 14 | minnedosa
# Processing Record 37 of Set 14 | birjand
# Processing Record 38 of Set 14 | general roca
# Processing Record 39 of Set 14 | rio grande
# Processing Record 40 of Set 14 | yalutorovsk
# Processing Record 41 of Set 14 | kamenka
# Processing Record 42 of Set 14 | ocampo
# Processing Record 43 of Set 14 | excelsior springs
# Processing Record 44 of Set 14 | linqiong
# Processing Record 45 of Set 14 | sterlibashevo
# Processing Record 46 of Set 14 | katherine
# Processing Record 47 of Set 14 | alugan
# Processing Record 48 of Set 14 | san pedro
# Processing Record 49 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 50 of Set 14 | vieksniai
# Processing Record 1 of Set 15 | stornoway
# Processing Record 2 of Set 15 | aden
# Processing Record 3 of Set 15 | sao jose da coroa grande
# Processing Record 4 of Set 15 | miramar
# Processing Record 5 of Set 15 | ulyanovo
# City not found. Skipping...
# Processing Record 6 of Set 15 | ewa beach
# Processing Record 7 of Set 15 | port augusta
# Processing Record 8 of Set 15 | khorinsk
# Processing Record 9 of Set 15 | hami
# Processing Record 10 of Set 15 | imbituba
# Processing Record 11 of Set 15 | alakurtti
# Processing Record 12 of Set 15 | richards bay
# Processing Record 13 of Set 15 | curvelo
# Processing Record 14 of Set 15 | harper
# Processing Record 15 of Set 15 | pokhara
# Processing Record 16 of Set 15 | luang prabang
# Processing Record 17 of Set 15 | la libertad
# Processing Record 18 of Set 15 | magdalena
# Processing Record 19 of Set 15 | basco
# Processing Record 20 of Set 15 | meghri
# Processing Record 21 of Set 15 | golden
# Processing Record 22 of Set 15 | cuamba
# Processing Record 23 of Set 15 | shitanjing
# Processing Record 24 of Set 15 | karratha
# Processing Record 25 of Set 15 | honningsvag
# Processing Record 26 of Set 15 | pavino
# Processing Record 27 of Set 15 | tigbinan
# Processing Record 28 of Set 15 | killybegs
# Processing Record 29 of Set 15 | presidencia roque saenz pena
# Processing Record 30 of Set 15 | lircay
# Processing Record 31 of Set 15 | handwara
# City not found. Skipping...
# Processing Record 32 of Set 15 | eyl
# Processing Record 33 of Set 15 | shahr-e kord
# Processing Record 34 of Set 15 | mbandaka
# ----------------------------
# Data Retriecal Complete
# ----------------------------

# %%
# confirming count

len(city_data)
# Out:
# 686

# %%
# NEW DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#         City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Rikitea      PF -23.1203 -134.9692     74.39        81         100
# 1       Juba      SS   4.8517   31.5825     72.23        82          38
# 2   Progreso      MX  21.2833  -89.6667     88.11        73          14
# 3      Sitka      US  57.0531 -135.3300     46.29        76          90
# 4    Kuusamo      FI  65.9667   29.1833     44.64        93          90
# 5     Iberia      US  29.9502  -91.7507     86.09        58           1
# 6  Busselton      AU -33.6500  115.3333     41.09        80          95
# 7       Lata      PT  40.1629   -8.3327     61.07        80          53
# 8      Vaini      TO -21.2000 -175.2000     80.76        78          20
# 9   Hopewell      US  37.3043  -77.2872     68.61        92         100
#
#    Wind Speed Current Description
# 0       18.32          light rain
# 1        3.89          light rain
# 2       12.88          few clouds
# 3       16.11       moderate rain
# 4        6.91     overcast clouds
# 5        6.91           clear sky
# 6        7.61     overcast clouds
# 7        2.53       broken clouds
# 8        5.75          light rain
# 9        7.85     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
